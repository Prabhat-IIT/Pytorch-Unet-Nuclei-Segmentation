# %%
from augmentation import augment_all,augment_random

# %%
patch_dir = '../Data/train-img256x256/'        # Directory of patch
binmask_dir = '../Data/train-bin-mask256x256/' # Directory of binary mask
patch_size = 256                               # patch size

# %%
augment_all(patch_dir,binmask_dir,patch_size)
# Out:
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# ...

# %%
augment_random(patch_dir,binmask_dir,patch_size)
# Out:
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# patch shape (256, 256, 3)
# mask shape (256, 256)
# ...
